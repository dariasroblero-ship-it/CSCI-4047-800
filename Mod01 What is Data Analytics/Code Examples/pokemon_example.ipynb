# %% [markdown]
# # In-Class Example
# I am reading data from `AllPokemon.csv` into a data frame.
#
# ## Steps:
# - Verify `Python` and `pip` are installed (`python --version` or `pip --version`).
# - Install the `pandas` package with `pip install pandas` in the terminal.
# - Write the program (see below).

# %%
python --version

# import pandas as pd

# df = pd.read_csv('AllPokemon.csv')
# df.head()
# Out:
#    Number        Name  Type1   Type2  Total  HP  Atk  Def  SpAtk  SpDef  Spd  \
# 0       1   Bulbasaur  Grass  Poison    318  45   49   49     65     65   45
# 1       2     Ivysaur  Grass  Poison    405  60   62   63     80     80   60
# 2       3    Venusaur  Grass  Poison    525  80   82   83    100    100   80
# 3       4  Charmander   Fire            309  39   52   43     60     50   65
# 4       5  Charmeleon   Fire            405  58   64   58     80     65   80
#
#    Gen
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
import pandas as pd, numpy as ny, sklearn as sl, seaborn as sb, statsmodels as sm, matplotlib as ml
print("Environment ready")

df = pd.read_csv('./AllPokemon.csv')
print(f"Extracted {len(df):,} rows and {len(df.columns)} columns")
df.head()
# Out:
# Environment ready
# Extracted 1,045 rows and 12 columns
#    Number        Name  Type1   Type2  Total  HP  Atk  Def  SpAtk  SpDef  Spd  \
# 0       1   Bulbasaur  Grass  Poison    318  45   49   49     65     65   45
# 1       2     Ivysaur  Grass  Poison    405  60   62   63     80     80   60
# 2       3    Venusaur  Grass  Poison    525  80   82   83    100    100   80
# 3       4  Charmander   Fire            309  39   52   43     60     50   65
# 4       5  Charmeleon   Fire            405  58   64   58     80     65   80
#
#    Gen
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
print(list(df['Type2']))
# Out:
# ['Poison', 'Poison', 'Poison', ' ', ' ', 'Flying', ' ', ' ', ' ', ' ', ' ', 'Flying', 'Poison', 'Poison', 'Poison', 'Flying', 'Flying', 'Flying', ' ', ' ', 'Flying', 'Flying', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'Ground', ' ', ' ', 'Ground', ' ', ' ', ' ', ' ', 'Fairy', 'Fairy', 'Flying', 'Flying', 'Poison', 'Poison', 'Poison', 'Grass', 'Grass', 'Poison', 'Poison', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'Fighting', ' ', ' ', ' ', ' ', ' ', ' ', 'Poison', 'Poison', 'Poison', 'Poison', 'Poison', 'Ground', 'Ground', 'Ground', ' ', ' ', 'Psychic', 'Psychic', 'Steel', 'Steel', 'Flying', 'Flying', 'Flying', ' ', 'Ice', ' ', ' ', ' ', 'Ice', 'Poison', 'Poison', 'Poison', 'Ground', ' ', ' ', ' ', ' ', ' ', ' ', 'Psychic', 'Psychic', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'Rock', 'Rock', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'Psychic', 'Fairy', 'Flying', 'Psychic', ' ', ' ', ' ', ' ', ' ', 'Flying', 'Ice', ' ', ' ', ' ', ' ', ' ', ' ', 'Water', 'Water', 'Water', 'Water'
# ...
